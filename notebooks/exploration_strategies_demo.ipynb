# %% [markdown]
# # Exploration Strategies in Reinforcement Learning
#
# This notebook demonstrates how to use the exploration strategies framework to compare different exploration methods in RL.
#
# ## Setup
